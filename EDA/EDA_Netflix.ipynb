# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Визуальный-анализ-рейтингов-шоу-Netflix" data-toc-modified-id="Визуальный-анализ-рейтингов-шоу-Netflix-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Визуальный анализ рейтингов шоу Netflix</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-признаков:" data-toc-modified-id="Описание-признаков:-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Описание признаков:</a></span></li></ul></li><li><span><a href="#Требования-к-групповому-проекту" data-toc-modified-id="Требования-к-групповому-проекту-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Требования к групповому проекту</a></span><ul class="toc-item"><li><span><a href="#Вопросы,-на-которые-нужно-ответить-в-презентации:" data-toc-modified-id="Вопросы,-на-которые-нужно-ответить-в-презентации:-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вопросы, на которые нужно ответить в презентации:</a></span></li><li><span><a href="#Полезные-замечания-и-советы" data-toc-modified-id="Полезные-замечания-и-советы-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Полезные замечания и советы</a></span></li></ul></li><li><span><a href="#Решение" data-toc-modified-id="Решение-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Решение</a></span><ul class="toc-item"><li><span><a href="#Удалите-из-данных-дубликаты." data-toc-modified-id="Удалите-из-данных-дубликаты.-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Удалите из данных дубликаты.</a></span></li><li><span><a href="#Сколько-рейтинговых-групп-представлено-в-данных?" data-toc-modified-id="Сколько-рейтинговых-групп-представлено-в-данных?-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Сколько рейтинговых групп представлено в данных?</a></span></li><li><span><a href="#Какие-оценки-пользователи-ставят-чаще?" data-toc-modified-id="Какие-оценки-пользователи-ставят-чаще?-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Какие оценки пользователи ставят чаще?</a></span></li><li><span><a href="#Выведите-основную-информацию-об-оценках-пользователей" data-toc-modified-id="Выведите-основную-информацию-об-оценках-пользователей-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Выведите основную информацию об оценках пользователей</a></span></li><li><span><a href="#В-какие-годы-были-запущены-шоу,-представленные-в-датасете?" data-toc-modified-id="В-какие-годы-были-запущены-шоу,-представленные-в-датасете?-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>В какие годы были запущены шоу, представленные в датасете?</a></span></li><li><span><a href="#Постройте-график,-показывающий-распределение-количества-запущенных-шоу-в-зависимости-от-года." data-toc-modified-id="Постройте-график,-показывающий-распределение-количества-запущенных-шоу-в-зависимости-от-года.-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Постройте график, показывающий распределение количества запущенных шоу в зависимости от года.</a></span></li><li><span><a href="#Сравните-среднюю-оценку-пользователей-в-2016-со-средней-оценкой-в-2017." data-toc-modified-id="Сравните-среднюю-оценку-пользователей-в-2016-со-средней-оценкой-в-2017.-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>Сравните среднюю оценку пользователей в 2016 со средней оценкой в 2017.</a></span></li><li><span><a href="#Как-нагляднее-будет-показать-распределение-пользователям-по-рейтинговым-группам?" data-toc-modified-id="Как-нагляднее-будет-показать-распределение-пользователям-по-рейтинговым-группам?-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>Как нагляднее будет показать распределение пользователям по рейтинговым группам?</a></span></li><li><span><a href="#Теперь-вам-нужно-выбрать-любое-из-представленных-шоу-и-при-помощи-изученных-инструментов-составить-описательный-портрет-этого-шоу-:)" data-toc-modified-id="Теперь-вам-нужно-выбрать-любое-из-представленных-шоу-и-при-помощи-изученных-инструментов-составить-описательный-портрет-этого-шоу-:)-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>Теперь вам нужно выбрать любое из представленных шоу и при помощи изученных инструментов составить описательный портрет этого шоу :)</a></span></li></ul></li></ul></li></ul></div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Визуальный анализ рейтингов шоу Netflix
# <img src="https://pp.userapi.com/c854528/v854528797/c62ce/FiPEibYUxJc.jpg" width="40%">

# %% [markdown]
# Netflix за последние 5-10 лет обзавелись большим количеством зрителей. С увеличением числа зрителей увеличилось и разнообразие шоу. Соответственно, перед аналитиками из киноиндустрии встала задача исследования данных с рейтингами различных сериалов.
# В данном задании вам предстоит провести визуальный анализ датасета **1000 Netflix Shows** (по состоянию на 11.06.2017) и сделать выводы.

# %% [markdown]
# ### Описание признаков:
# * `title` - название шоу.
# * `rating` - рейтинг шоу. Например: G, PG, TV-14, TV-MA.
# * `ratingLevel` - описание рейтинговой группы и особенностей шоу.
# * `ratingDescription` - рейтинг шоу, закодированный в числом.
# * `release year` - год выпуска шоу.
# * `user rating score` - оценка пользователей.
# * `user_rating_size` - общий рейтинг пользователей.

# %% [markdown]
# ## Требования к групповому проекту
#
# В качестве результата ваша группа должна получить презентацию и защитить ее на дополнительном занятии.
# Ссылка на шаблон к презентации: лежит рядом с заданием в классруме.
# Вы можете менять оформление презентации, но помните, что результат должен быть релевантен для демонстрации заказчику. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не стоит :)
#
# Помимо презентации, каждому из участников проекта нужно будет сдать свой notebook c решением на проверку. Наши ассистенты проверять ваш код, визуализацию и выводы.
#
# ### Вопросы, на которые нужно ответить в презентации:
# - Сколько рейтинговых групп представлено в данных?
# - Какие оценки пользователи ставят чаще всего?
# - Какие оценки пользователи ставят в среднем?
# - В какие годы были запущены шоу?
# - Можно ли сделать вывод, что 2017 год успешнее для Netflix?
# - В каких рейтинговых группах запущены шоу на Netflix?
# - Выберите любое шоу (например, самое понравившееся) и составьте его описательный портрет. На какие вопросы о нем вам было бы интересно ответить, если бы вы были заказчиком? Ответьте на эти вопросы :)
#
# Вопросы ниже помогут вам ответить на вопросы из презентации и сопроводить выводы релевантной визуализацией.
#
# Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами. Как пример, вы можете распределить вопросы/слайды между собой.
#
# ### Полезные замечания и советы
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев;
# - Не нужно делать просто текстовые слайды;
# - Не обязательно ограничиваться представленным датасетом. У вас есть весь интернет, чтобы найти дополнительную информацию и проверить ваши гипотезы. Дерзайте!

# %% [markdown]
# ## Решение

# %% [markdown]
# Скачайте данные: они лежат рядом с этим файлом в классруме.
# Загрузите данные, выполнив код ниже.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72410ab2-b5c6-4457-ae8b-fe7c49cc3bd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72410ab2-b5c6-4457-ae8b-fe7c49cc3bd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("NetflixShows - NetflixShows.csv", encoding='cp437')
del data['ratingDescription'], data['user rating size']

# %% [markdown]
# ### Удалите из данных дубликаты.
# - Почему они возникли?
# - Много ли их? В каких группах их больше всего?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingLevel        941 non-null    object
#  3   release year       1000 non-null   int64
#  4   user rating score  605 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
#Удаялем полностью дублирующие друг друга строки. 
data_1 = data.drop_duplicates(ignore_index=True) 
data_1.shape
# Out:
# (500, 5)

# %%
#Дополнительно выводим список неуникальных названий шоу
mask = data_1['title'].value_counts()[data_1['title'].value_counts() > 1].index
data_1[data_1['title'].isin(mask)]

#По данным видно что дубли связанные с перевыпуском или ремейком шоу. Принимаем решение оставить их в датасете
# Out:
#                          title rating  \
# 119                      Skins  TV-MA
# 128                 Bordertown  TV-14
# 135                      Skins  TV-MA
# 257                 Bordertown  TV-MA
# 269  Star Wars: The Clone Wars     PG
# 276  Star Wars: The Clone Wars  TV-PG
# 321                 Goosebumps  TV-Y7
# 366                 Goosebumps     PG
#
#                                            ratingLevel  release year  \
# 119  For mature audiences.  May not be suitable for...          2013
# 128  Parents strongly cautioned. May be unsuitable ...          2016
# 135                                                NaN          2017
# 257  For mature audiences.  May not be suitable for...          2016
# 269  sci-fi action violence throughout, brief langu...          2008
# 276  Parental guidance suggested. May not be suitab...          2014
# 321             Suitable for children ages 7 and older          1998
# ...

# %% [markdown]
# 2.

# %%
#Чтобы оценть в каких именно группах и сколько было пропусков сделаем группировку и построим два графика, с абсалютным значением пропусков и относительным значением.
data_gap_diff = (data.groupby('rating')['title'].count() - data_1.groupby('rating')['title'].count()).reset_index()
data_gap_ratio = (((data.groupby('rating')['title'].count() / data_1.groupby('rating')['title'].count())-1)*100).reset_index()

# %%
#Отрисовка графиков 
fig, axs = plt.subplots(ncols=2, figsize=(20, 7))

sns.barplot(x='rating',y='title', data=data_gap_diff, color='#ff8e89', order=data_gap_diff.sort_values('title').rating, ax=axs[0])
axs[0].set_xlabel('Rating', fontsize= 16 )
axs[0].set_ylabel('Count', fontsize= 16 )
axs[0].set_title('Количество пропусков по группам', fontsize= 20 )
axs[0].set_xticklabels(axs[0].get_xticklabels(), fontsize= 9)
#axs[0].set_yticklabels(axs[0].get_yticklabels(), fontsize= 14)

sns.barplot(x='rating', y='title', data=data_gap_ratio, color='#ff3d85', order=data_gap_ratio.sort_values('title').rating, ax=axs[1])
axs[1].set_xlabel('Rating', fontsize= 16 )
axs[1].set_ylabel('%', fontsize= 16 )
axs[1].set_title('Процент пропусков по группам', fontsize= 20 )
axs[1].set_xticklabels(axs[1].get_xticklabels(), fontsize= 9)
#axs[1].set_yticklabels(axs[1].get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %% [markdown]
# ### Сколько рейтинговых групп представлено в данных?

# %%
#Смотрим сколько рейтинговых груп представленно в датасете. Ответ 13
len(data_1['rating'].unique())
# Out:
# 13

# %% [markdown]
# ### Какие оценки пользователи ставят чаще?
#
# - Постройте гистограмму оценок.
# - Почему именно такие оценки ставят чаще всего?

# %%
#Перед тем как дальше работать с данными посмотрим на пропуски
data_1.info()

#Видим что в пользовательских оценках очень много пропусков, но т.к. дополнительной информации о пользователях нет принимаем
#решение не востанавливать оценки и продолжить анализ на имеющихся данных. Позже посмотрим можно ли в место пропусков вставить среднее значение по группировки "год"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              500 non-null    object
#  1   rating             500 non-null    object
#  2   ratingLevel        467 non-null    object
#  3   release year       500 non-null    int64
#  4   user rating score  256 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 19.7+ KB

# %%
# Строим гистограмму распределения столбца 'user rating score' для всех шоу сразу и отдельно для ТВ-шоу и фильмов

user_rating_score_all=data_1.groupby("user rating score")['title'].count().reset_index().sort_values('user rating score',ascending=False).astype(int)

fig, axs = plt.subplots(figsize=(20, 7))

sns.barplot(x='user rating score',y='title', data=user_rating_score_all, color='#75d4ff', ax=axs)
axs.set_xlabel(None)
axs.set_ylabel('Count', fontsize= 16 )
axs.set_title('Оценки пользователей по всем шоу', fontsize= 20 )
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)

...
# Out:
# Ellipsis

# %%
data_TV = data_1[data_1['rating'].str.contains('TV')]
user_rating_score_TV = data_TV.groupby("user rating score")['title'].count().reset_index().sort_values('user rating score',ascending=False).astype(int)

fig, axs = plt.subplots(figsize=(20, 7))
sns.barplot(x='user rating score',y='title', data=user_rating_score_TV, color='#65ffd2', ax=axs)
axs.set_xlabel(None)
axs.set_ylabel('Count', fontsize= 16 )
axs.set_title('Оценки пользователей только по ТВ-шоу', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %%
data_films = data_1[~data_1['rating'].str.contains('TV')]
user_rating_score_films = data_films.groupby("user rating score")['title'].count().reset_index().sort_values('user rating score',ascending=False).astype(int)

fig, axs = plt.subplots(figsize=(20, 7))
sns.barplot(x='user rating score',y='title', data=user_rating_score_films, color='#ffbb84', ax=axs)
axs.set_xlabel(None)
axs.set_ylabel('Count', fontsize= 16 )
axs.set_title('Оценки пользователей только по фильмам', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %% [markdown]
# ### Выведите основную информацию об оценках пользователей
# - Чему равны среднее, стандартное отклонение, минимум, максимум, медиана?
# - Отличаются ли медиана и среднее?
# - Могут ли данные характеристики значительно отличаться? Почему?

# %%
#Для простоты кода воспользуемся стандартными функциями pandas чтоб вывести статистическую информацию по пользовательским оценкам
print('Статистическая инфомрация о пользовательских оценках:')
print('Среднее арифметическое - %.2f' %data_1['user rating score'].mean())
print('Стандартное отклонение - %.2f' %data_1['user rating score'].std())
print('Минимум - %.2f' %data_1['user rating score'].min())
print('Максимум - %.2f' %data_1['user rating score'].max())
print('Медиана - %.2f' %data_1['user rating score'].median())

#Не использован метод describe потому что так захотели
#Ответ на второй вопрос: медиана и среднее занчение отличаются т.к. распределение оценок является ассиметричным и смещенным вправо.
#Ответ на третий вопрос: да, медиана и среднее занчение могут значительно отличатся в случае ассиметричного распределения. 
#К примеру для [1,1,2,2,2,3,3,1000] медиана будет равна 2 а среднее 127.
# Out:
# Статистическая инфомрация о пользовательских оценках:
# Среднее арифметическое - 81.40
# Стандартное отклонение - 12.73
# Минимум - 55.00
# Максимум - 99.00
# Медиана - 83.50

# %% [markdown]
# ### В какие годы были запущены шоу, представленные в датасете?

# %%
start = data_1['release year'].min()
end = data_1['release year'].max()
print(f'Год выпуска шоу в просматриваемом датасете с {start} по {end} гг')
# Out:
# Год выпуска шоу в просматриваемом датасете с 1940 по 2017 гг

# %% [markdown]
# ### Постройте график, показывающий распределение количества запущенных шоу в зависимости от года.
#
# - Наблюдается ли рост?
# - Есть ли выбросы?
# - Что из себя представляют выбросы?
# - Чем могут быть они вызваны?

# %%
data_1["release year"].value_counts()
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
sns.boxplot(y=data_1["release year"].value_counts().index, x=data_1["release year"].value_counts())
# Out:
# <AxesSubplot:xlabel='release year'>

# %%
fig, axs = plt.subplots(nrows=1, figsize=(10, 5))
sns.boxplot(y=data_1['release year'], color='#d5b8ff')

per25 = data_1["release year"].describe()["25%"]
per75 = data_1["release year"].describe()["75%"]

iqr = per75 - per25
mask = (data_1["release year"] > per25 - iqr*1.5) & (data_1["release year"] < per75 + iqr*1.5)
print(f'К не выбросам относим шоу выпущенные с {data_1["release year"][mask].min()} по {data_1["release year"][mask].max()}')
# Out:
# К не выбросам относим шоу выпущенные с 1999 по 2017

# %%
fig, axs = plt.subplots(ncols=1, figsize=(20,10))
sns.boxplot(data=data_1, y='user rating score', x="rating", palette='pastel')
sns.stripplot(data=data_1, y='user rating score', x="rating", color='blue', size=4, jitter=0.15)
axs.set_xlabel(None)
axs.set_ylabel('Score', fontsize= 16 )
axs.set_title('Распределение оценок по каждой группе отдельно', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %%
fig, axs = plt.subplots(ncols=1, figsize=(20,10))
sns.boxplot(data=data_1, y='release year', x="rating", palette='pastel')
axs.set_xlabel(None)
axs.set_ylabel('Year', fontsize= 16 )
axs.set_title('Выбросы по каждой группе отдельно', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %%
#Сначала сгрупируем фрейм данных по годам и оставим серию данных с количеством шоу в каждом году
data_grouped_year = data.groupby('release year')['title'].count().reset_index()

#Теперь выведем график с количеством запущенных шоу в году
fig, axs = plt.subplots(ncols=1, figsize=(20, 7))

sns.barplot(x='release year',y='title', data=data_grouped_year, color='#5961ff')

for i, val in enumerate(data_grouped_year['title'].values):
    plt.text(i, val, float(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':100, 'size':11})
    
axs.set_xlabel('Year', fontsize= 16 )
axs.set_ylabel('Count', fontsize= 16 )
axs.set_title('Динамика выпущенных шоу', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# Ellipsis

# %%
data_mean_years.head(2)
# Out:
#               user rating score
# release year
# 1940                       61.0
# 1976                        NaN

# %%
data_mean_years = data_1.groupby(['release year']).mean(numeric_only=True).sort_index()
axs = data_mean_years[-15:].plot(figsize=(20, 7), linewidth= 5)
axs.set_xlabel('Release year', fontsize= 16 )
axs.set_ylabel('Mean score', fontsize= 16 )
axs.set_title('Динамика оценки по годам', fontsize= 20 )
#axs.set_xticklabels(axs.get_xticklabels(), fontsize= 11)
#axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
# Out:
# Text(0.5, 1.0, 'Динамика оценки по годам')

# %%
#1. Наблюдается ли рост? - да. С момента запуска сервиса в 1997 году после плато на графике виден рост с 2010 года. 
#Он связан с выходом на международный рынок.

#2-4. Есть ли выбросы? - да. Сильно выделятся количество выпущенных фильмов в 2016 году. 
#Их 146 штук, что выше среднего или медианы распределения на порядок. 
#Но собрав в сети дополнительную информацию данный скачок обусловлен увеличением стран присутсвия 
#стриминговой платформы и не может быть принят как выброс.
#Выпущенные шоу до года создания Netflix в 1997 году не принимаем как выбросы т.к. год выпуска шоу не означает год выпуска шоу на Netflix.
#Так же за интерквартильный размах относятся все шоу выпущенные до 1999 года

#Для полноты картины посчитаем % выпущенных шоу за период с 1997 год. Получим 95%
share_of_films = (data_grouped_year.loc[1997:2017].sum() / data_grouped_year.sum())*100
print(share_of_films)
# Out:
# release year    0.0
# title           0.0
# dtype: float64

# %% [markdown]
# ### Сравните среднюю оценку пользователей в 2016 со средней оценкой в 2017.
# - Можно ли сделать вывод, что 2017 год успешнее для Netflix? ("Успешнее" значит, что пользователи в среднем ставили более высокие оценки)
# - Как еще можно оценить "Успешность"?

# %%
data_end_1 = data_1.groupby('release year').mean(numeric_only=True).loc[[2016, 2017]]
percent = ((data_end_1.loc[2017].values / data_end_1.loc[2016].values)-1)*100
print(f'В 2017 году в среднем оценка стала выще на {percent} %')
# Out:
# В 2017 году в среднем оценка стала выще на [4.5200662] %

# %%
data_end_2 = data_1.groupby('release year').count().loc[[2016, 2017]][['title', 'user rating score']]
data_end_2

#В качестве успешности еще будем рассматривать кол-во выпущенных фильмов и оценок пользователей в этих года
# Out:
#               title  user rating score
# release year
# 2016            146                 86
# 2017             37                 16

# %%
#Так же в качестве оценки по годам используем стандартные методы из описательной статистики
data_end_3 = pd.DataFrame()
data_end_3['mean'] = data_1.groupby('release year').mean().loc[[2016, 2017]]['user rating score']
data_end_3['std'] = data_1.groupby('release year').std().loc[[2016, 2017]]['user rating score']
data_end_3['min'] = data_1.groupby('release year').min('user rating score').loc[[2016, 2017]]['user rating score']
data_end_3['max'] = data_1.groupby('release year').max('user rating score').loc[[2016, 2017]]['user rating score']
data_end_3['median'] = data_1.groupby('release year').median().loc[[2016, 2017]]['user rating score']
data_end_3.index.name = 'user rating score'
data_end_3
# Out:
#                         mean        std   min   max  median
# user rating score
# 2016               84.313953  12.599030  56.0  98.0    89.0
# 2017               88.125000   8.585841  71.0  99.0    90.5

# %%
data_1.groupby(['release year', 'rating']).mean(numeric_only=True).loc[[2016, 2017]]
#Нет смысла рассматривать с разбивкой по годам отдельные рейтинговые группы из за большого кол-ва пропусков таргетного значения.
# Out:
#                        user rating score
# release year rating
# 2016         G                 80.000000
#              NR                97.000000
#              PG                90.000000
#              R                 90.750000
#              TV-14             83.972222
#              TV-G              70.666667
#              TV-MA             82.210526
#              TV-PG             88.000000
#              TV-Y              77.000000
#              TV-Y7             85.000000
#              TV-Y7-FV          77.333333
#              UR                      NaN
# 2017         TV-14             91.500000
#              TV-MA             88.916667
#              TV-PG                   NaN
#              TV-Y7             72.000000
#              TV-Y7-FV          88.000000

# %% [markdown]
# ### Как нагляднее будет показать распределение пользователям по рейтинговым группам?
#
# Ниже представлены два графика, показывающие распределение шоу по рейтинговым группам. Какой тип графика визуально более интерпретируемый? ([Подсказка](https://sun9-40.userapi.com/c854228/v854228652/c754f/j6z5gMjJy2k.jpg))
# Постройте самостоятельно график, который считаете более интерпретируемым. Сделайте вывод.

# %% [markdown]
# ![Charts](https://pp.userapi.com/c852024/v852024281/1a53b1/jSOsBIhxK3U.jpg)

# %%
data_for_charts = data_1.groupby('rating')['title'].count().to_frame()
data_for_charts = data_for_charts.assign(percent = lambda x: x['title']/data_for_charts['title'].sum()*100)
#data_for_charts['percent'].plot(kind='pie', figsize=(10, 10), title=, autopct='%1.0f%%')

axs = data_for_charts['percent'].plot(kind='pie', figsize=(15, 15), autopct='%1.0f%%',fontsize=16)
axs.set_xlabel(None)
axs.set_ylabel('Percent', fontsize= 16 )
axs.set_title('Распределение шоу по рейтингам', fontsize= 20 )
axs.set_xticklabels(axs.get_xticklabels(), fontsize= 14)
axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
axs.legend(title = 'rating', loc=1,fontsize=20, prop={'size': 12});

#Из диаграммы можно сдеалть вывод что более 50% шоу выпускаются с рейтингом G, PG, TV-MA, TV-14.

# %% [markdown]
# ### Теперь вам нужно выбрать любое из представленных шоу и при помощи изученных инструментов составить описательный портрет этого шоу :)
# Аналитики и Data Scientist-ы очень любят все сравнивать, поэтому при составлении описательного портрета рекомендуем вам сравнить выбранное шоу с другими по каким-либо характеристикам. Результаты не забудьте внести в презентацию. При возникновении трудностей обязательно пишите в чат, преподавателю или ассистентам.

# %%
data_1[data_1['title'] == 'Sherlock']
# Out:
#        title rating                                        ratingLevel  \
# 11  Sherlock  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#     release year  user rating score
# 11          2016               95.0

# %%
data_1[data_1['title'] == 'Sherlock']['user rating score'].values[0]
# Out:
# 95.0

# %%
Sherlock = data_1[data_1['title'] == 'Sherlock']['user rating score'].values[0]
all_x = round(data_1['user rating score'].mean(), 1)
year_x = round(data_1[data_1['release year'] == 2016]['user rating score'].mean(), 1)
group_x = round(data_1[data_1['rating'] == 'TV-14']['user rating score'].mean(), 1)

fig, axs = plt.subplots(ncols=1, figsize=(21,7))
sns.barplot(x=['Sherlock', 'Mean_Netflix', 'Mean_Year_2016', 'Mean_Group_TV-14'], y=[Sherlock, all_x, year_x, group_x], palette='pastel')

for i, val in enumerate([Sherlock, all_x, year_x, group_x]):
    plt.text(i, val, float(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':100, 'size':15})

axs.set_xlabel(None)
axs.set_ylabel('Score', fontsize= 16 )
axs.set_title('Оценка пользователей', fontsize= 20 )
axs.set_xticklabels(axs.get_xticklabels(), fontsize= 14)
axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
...
# Out:
# <ipython-input-147-25f9350e050d>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
# Ellipsis

# %%
data_1['rating'].unique()
# Out:
# array(['PG-13', 'R', 'TV-14', 'TV-PG', 'TV-MA', 'TV-Y', 'NR', 'TV-Y7-FV',
#        'UR', 'PG', 'TV-G', 'G', 'TV-Y7'], dtype=object)

# %%
rating_dict = {'PG-13': '13+',
               'TV-Y7': '7+', 
               'R': '17+', 
               'TV-14': '14+', 
               'TV-PG': '0+', 
               'TV-MA': '17+', 
               'TV-Y': '0+', 
               'NR': '0+', 
               'TV-Y7-FV': '7+',
               'UR': '0+', 
               'PG': '0+', 
               'TV-G': '0+', 
               'G': '0+', 
               }
data_rating_score = data_1.copy()
data_rating_score['rating'] = data_rating_score['rating'].replace(rating_dict)
data_rating_score = data_rating_score.groupby('rating')['title'].count().to_frame()
data_rating_score = data_rating_score.assign(percent = lambda x: x['title']/data_rating_score['title'].sum()*100)
data_rating_score = pd.concat([data_rating_score[:1], data_rating_score[-1:], data_rating_score[1:4]])
axs = data_rating_score['percent'].plot(kind='pie', figsize=(15, 15), autopct='%1.0f%%',fontsize=16)
axs.set_xlabel(None)
axs.set_ylabel('Percent', fontsize= 16 )
axs.set_title('Распределение шоу по возрастным группам', fontsize= 20 )
axs.set_xticklabels(axs.get_xticklabels(), fontsize= 14)
axs.set_yticklabels(axs.get_yticklabels(), fontsize= 14)
axs.legend(title = 'age groups', loc=1,fontsize=20, prop={'size': 14});

# %%
#The END
